# %%
import csv
import json
import numpy as np
import pandas as pd

# %%
avalon = pd.read_csv('data.csv', names = ('Sex', 'Length', 'Diameter','Height','Whole','Shucked','Viscera','Shell','Rings'))

# %%
type(avalon)
# Out:
# pandas.core.frame.DataFrame

# %%
avalon.head()
# Out:
#   Sex  Length  Diameter  Height   Whole  Shucked  Viscera  Shell  Rings
# 0   M   0.455     0.365   0.095  0.5140   0.2245   0.1010  0.150     15
# 1   M   0.350     0.265   0.090  0.2255   0.0995   0.0485  0.070      7
# 2   F   0.530     0.420   0.135  0.6770   0.2565   0.1415  0.210      9
# 3   M   0.440     0.365   0.125  0.5160   0.2155   0.1140  0.155     10
# 4   I   0.330     0.255   0.080  0.2050   0.0895   0.0395  0.055      7

# %%
avalon.to_csv('data_re.csv')

# %%
result = []

# %%
with open ('data_re.csv') as f:
    for line in csv.DictReader(f):
        line_json = json.dumps(line)
        result.append(line_json)
print(result)
# Out:
# ['{"": "0", "Sex": "M", "Length": "0.455", "Diameter": "0.365", "Height": "0.095", "Whole": "0.514", "Shucked": "0.2245", "Viscera": "0.10099999999999999", "Shell": "0.15", "Rings": "15"}', '{"": "1", "Sex": "M", "Length": "0.35", "Diameter": "0.265", "Height": "0.09", "Whole": "0.2255", "Shucked": "0.0995", "Viscera": "0.0485", "Shell": "0.07", "Rings": "7"}', '{"": "2", "Sex": "F", "Length": "0.53", "Diameter": "0.42", "Height": "0.135", "Whole": "0.677", "Shucked": "0.2565", "Viscera": "0.1415", "Shell": "0.21", "Rings": "9"}', '{"": "3", "Sex": "M", "Length": "0.44", "Diameter": "0.365", "Height": "0.125", "Whole": "0.516", "Shucked": "0.2155", "Viscera": "0.114", "Shell": "0.155", "Rings": "10"}', '{"": "4", "Sex": "I", "Length": "0.33", "Diameter": "0.255", "Height": "0.08", "Whole": "0.205", "Shucked": "0.0895", "Viscera": "0.0395", "Shell": "0.055", "Rings": "7"}', '{"": "5", "Sex": "I", "Length": "0.425", "Diameter": "0.3", "Height": "0.095", "Whole": "0.3515", "Shucked": "0
# ...

# %%
type(result)
# Out:
# list

# %%
fw = open('data.json','w')
#ココ重要！！
# json.dump関数でファイルに書き込む
json.dump(result,fw,indent=4)

# %%
test = json.load('data.json', 'r')
